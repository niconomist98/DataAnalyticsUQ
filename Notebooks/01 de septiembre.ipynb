# %%
# #Importando las librerias necesarias para el analisis de la GEIH
import pandas as pd
import numpy as np

# %%
df_emicron=pd.read_csv('https://raw.githubusercontent.com/niconomist98/DataAnalyticsUQ/refs/heads/main/Datos/EMICRON/emicron_identificacion.csv', encoding='latin', sep= ',')

# %%
total_micronegocios_agricultura = df_emicron[df_emicron['GRUPOS12'] == 1]['F_EXP'].sum()
print("Total de micronegocios en el sector de agricultura:", total_micronegocios_agricultura)
# Out:
# Total de micronegocios en el sector de agricultura: 1138758.1274708195

# %%
df_emicron['GRUPOS12'].unique()
# Out:
# array([ 3,  1,  5,  7,  6,  9,  4, 12, 11,  8,  2, 10, 13])

# %%
#datos miembros del congreso

df=pd.read_csv('https://unitedstates.github.io/congress-legislators/legislators-current.csv')

# %%
n_by_gender = df.groupby([ "state","gender"])["first_name"].count()
n_by_gender
# Out:
# state  gender
# AK     F         1
#        M         2
# AL     F         2
#        M         7
# AR     M         6
#                 ..
# WI     M         8
# WV     F         2
#        M         2
# WY     F         2
#        M         1
# Name: first_name, Length: 100, dtype: int64

# %%
df
# Out:
#       last_name first_name middle_name suffix nickname           full_name  \
# 0      Cantwell      Maria         NaN    NaN      NaN      Maria Cantwell
# 1     Klobuchar        Amy        Jean    NaN      NaN       Amy Klobuchar
# 2       Sanders    Bernard         NaN    NaN   Bernie     Bernard Sanders
# 3    Whitehouse    Sheldon         NaN    NaN      NaN  Sheldon Whitehouse
# 4      Barrasso       John          A.    NaN      NaN       John Barrasso
# ..          ...        ...         ...    ...      ...                 ...
# 533      Husted        Jon       Allen    NaN      NaN          Jon Husted
# 534       Moody     Ashley      Brooke    NaN      NaN        Ashley Moody
# 535    Patronis      Jimmy        Theo    Jr.      NaN      Jimmy Patronis
# 536        Fine    Randall        Adam    NaN    Randy          Randy Fine
# 537  Walkinshaw      James          R.    NaN      NaN                 NaN
#
#        birthday gender type state  ...  opensecrets_id  lis_id  \
# ...

# %%
micronegocios_por_dpto = df_emicron[df_emicron['P35']==2].groupby(["COD_DEPTO"])["F_EXP"].sum()
dpto_nombre = {
    91: 'AMAZONAS',
    81: 'ARAUCA',
    5: 'ANTIOQUIA',
    8: 'ATLANTICO',
    11: 'BOGOTA',
    13: 'BOLIVAR',
    15: 'BOYACA',
    17: 'CALDAS',
    18: 'CAQUETA',
    19: 'CAUCA',
    85: 'CESAR',
    23: 'CORDOBA',
    25: 'CUNDINAMARCA',
    27: 'CHOCO',
    19: 'CAUCA',
    20: 'CESAR',
    23: 'CORDOBA',
    25: 'CUNDINAMARCA',
    27: 'CHOCO',
    20: 'CESAR',
    23: 'CORDOBA',
    25: 'CUNDINAMARCA',
    27: 'CHOCO',
    41: 'HUILA',
    44: 'GUAJIRA',
    47: 'MAGDALENA',
    50: 'META',
    52: 'NARIÑO',
    54: 'NORTE DE SANTANDER',
    86: 'PUTUMAYO',
    88: 'SAN ANDRES',
    68: 'SANTANDER',
    70: 'SUCRE',
    73: 'TOLIMA',
    76: 'VALLE DEL CAUCA',
    90: 'CASANARE',
    98: 'PUTUMAYO',
    63: 'QUINDIO',
    66: 'RISARALDA',
    68: 'SANTANDER',
    94: 'GUAINIA',
    95: 'GUAVIARE',
    97: 'VAUPES',
    99: 'VICHADA'
}
micronegocios_por_dpto.index = micronegocios_por_dpto.index.map(dpto_nombre)
micronegocios_por_dpto.sort_values(ascending=False)
# Out:
# COD_DEPTO
# ANTIOQUIA             228065.054284
# BOGOTA                218597.578012
# VALLE DEL CAUCA       187779.989543
# NARIÑO                163404.046726
# ATLANTICO             127459.192128
# CORDOBA                99508.457678
# SANTANDER              96198.312413
# BOLIVAR                89256.882936
# CAUCA                  87585.021376
# CUNDINAMARCA           68092.478848
# MAGDALENA              61369.107902
# CESAR                  53543.138605
# GUAJIRA                51573.204613
# BOYACA                 47304.823258
# NORTE DE SANTANDER     46762.417691
# META                   43425.064565
# SUCRE                  41727.424606
# TOLIMA                 37552.765464
# HUILA                  30260.144557
# CALDAS                 27679.193558
# RISARALDA              25972.155798
# QUINDIO                16095.311503
# CAQUETA                15187.450504
# CHOCO                  10876.912625
# SAN ANDRES               650.468304
# Name: F_EXP, dtype: float64
