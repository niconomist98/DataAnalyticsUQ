# %%
# #Importando las librerias necesarias para el analisis de la GEIH
import pandas as pd
import numpy as np

# %%
#Leyendo los datos de la geih
df_cgsse = pd.read_csv('https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/cgsse.CSV'
                       ,encoding='latin',sep=';'
                       )

df_o = pd.read_csv('https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/Ocupados.CSV'
                       ,encoding='latin',sep=';'
                       )

df_d = pd.read_csv('https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/No%20ocupados.CSV'
                       ,encoding='latin',sep=';'
                       )
df_ft = pd.read_csv('https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/Fuerza%20de%20trabajo.CSV'
                       ,encoding='latin',sep=';'
                       )
# Out:
# /tmp/ipykernel_11718/3175422324.py:6: DtypeWarning: Columns (28,89,133,147,158) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_o = pd.read_csv('https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/Ocupados.CSV'
# /tmp/ipykernel_11718/3175422324.py:13: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ft = pd.read_csv('https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/Fuerza%20de%20trabajo.CSV'

# %%
# Calculo de la PEA
PEA = df_ft[df_ft['FT']==1]['FEX_C18'].sum()
print(f'La PEA es: {PEA}')

# Calculo de la PEI
PEI = df_ft[df_ft['FFT']==1]['FEX_C18'].sum()
print(f'La PEI es: {PEI}')
# Out:
# La PEA es: 25974846.22356785
# La PEI es: 14678569.776436238

# %%
25974846.22356785+14678569.776436238
# Out:
# 40653416.00000409

# %%
# Calculo de la PEI
PET = df_ft[df_ft['PET']==1]['FEX_C18'].sum()
print(f'La PET es: {PET}')
# Out:
# La PET es: 40653416.00000409

# %%
PT = df_cgsse['FEX_C18'].sum()
print(f'La PT es: {PT}')
# Out:
# La PT es: 52045001.000009045

# %%
PNET = PT - PET
print(f'La PNET es: {PNET:.2%}')
# Out:
# La PNET es: 1139158500.00%
