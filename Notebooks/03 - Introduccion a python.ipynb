# %% [markdown]
# Como imprimir texto en python:
# **Para imprimir text en python , usamos la funcion print()**

# %%
#Esto es un comentario 
#asdsadasd

"""
Esto es un comentario multilinea
esto es otra linea del comentario
esto es otra linea del comentario
"""

print("Hello")
print(1+2)

# %% [markdown]
# Usando python como una calculadora

# %%
10/5

# %% [markdown]
# Creando variables en python

# %%
edad = 18 
print(edad+10)

# %% [markdown]
# Tipos de variables en python

# %% [markdown]
# 1. Variables tipo string

# %%
nombre = 'Nicolas'
print(nombre)
print(type(nombre))

# %% [markdown]
# 2. Variable tipo numero  entero

# %%
edad = 18
print(edad)
print(type(edad))

# %% [markdown]
# 3. Variable tipo numero decimal

# %%
estatura = 1.8 
print(estatura)
print(type(estatura))

# %% [markdown]
# 4. Variable tipo booleano

# %%
es_mayor_de_edad = True 
es_menor_de_edad= False
print (es_mayor_de_edad)
print(type(es_mayor_de_edad))

# %%
print('nicolas'+'restrepo')

# %%
print(2**2)

# %%
print('nicolas'*2)

# %% [markdown]
# Operaciones matematicas basicas en python

# %%
#Suma
print(2+2)
#Resta
print(2-2)
#Multiplicacion
print(2*2)
#Division
print(2/2)
#Division entera
print(2//2)
#Modulo
print(2%2)
#Potencia
print(2**2)

# %%
activo =1500000
pasivo=2000000
print(activo+pasivo)
print(activo-pasivo)
print(activo*pasivo)
print(activo/pasivo)

# %% [markdown]
# Elementos importantes a la hora de crear nombres de variables

# %%
# Siempre procurar nombres de variables sencillos, concretos y dicientes
inflacion = 4.5

#Lower case 
nombre = 'Nicolas'

#underscore
nombre_completo = 'Nicolas Restrepo'

#Camel Case
nombreCompleto = 'Nicolas Restrepo'

#CONSTANTE
NOMBRE = 3.141592654

# %%
# Cosas que no se pueden hacer

1materia = 'electiva'

nombre-completo = 'Nicolas Restrepo'
