# %% [markdown]
# 1. Se crea el esquema electiva, para almacenar todas las tablas con las que vamos a trabajar

# %%
# %sql
USE SCHEMA electiva;
DROP TABLE IF EXISTS workspace.electiva.customers;

# %%
import pandas as pd
import requests
from io import StringIO

# Leer datos desde GitHub
url = "https://raw.githubusercontent.com/niconomist98/DataAnalyticsUQ/202602/DATOS/OCUPADOS.CSV"
response = requests.get(url)
response.encoding = 'utf-8'

# Crear DataFrame de pandas
df = pd.read_csv(StringIO(response.text),sep=';')

# Mostrar información del DataFrame
print(f"Dimensiones: {df.shape}")
print(f"\nPrimeras filas:")
display(df.head())
# Convertir a Spark DataFrame
df_spark = spark.createDataFrame(df)

# Guardar como tabla Delta en el catálogo
# Ajusta el nombre de la tabla según tu catálogo y esquema
table_name = "workspace.electiva.cgse"
df_spark.write.format("delta").mode("overwrite").saveAsTable(table_name)

print(f"\nTabla guardada exitosamente como: {table_name}")

# %%
import pandas as pd
import requests
from io import StringIO

# Leer datos desde GitHub
url = "https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/202602/DATOS/CGSE.CSV"
response = requests.get(url)
response.encoding = 'utf-8'

# Crear DataFrame de pandas
df = pd.read_csv(StringIO(response.text),sep=';')

# Mostrar información del DataFrame
print(f"Dimensiones: {df.shape}")
print(f"\nPrimeras filas:")
display(df.head())
# Convertir a Spark DataFrame
df_spark = spark.createDataFrame(df)

# Guardar como tabla Delta en el catálogo
# Ajusta el nombre de la tabla según tu catálogo y esquema
table_name = "workspace.electiva.cgse"
df_spark.write.format("delta").mode("overwrite").saveAsTable(table_name)

print(f"\nTabla guardada exitosamente como: {table_name}")

# %%
import pandas as pd
import requests
from io import StringIO

# Leer datos desde GitHub
url = "https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/202602/DATOS/FT.CSV"
response = requests.get(url)
response.encoding = 'utf-8'

# Crear DataFrame de pandas
df = pd.read_csv(StringIO(response.text),sep=';')

# Mostrar información del DataFrame
print(f"Dimensiones: {df.shape}")
print(f"\nPrimeras filas:")
display(df.head())
# Convertir a Spark DataFrame
df_spark = spark.createDataFrame(df)

# Guardar como tabla Delta en el catálogo
# Ajusta el nombre de la tabla según tu catálogo y esquema
table_name = "workspace.electiva.ft"
df_spark.write.format("delta").mode("overwrite").saveAsTable(table_name)

print(f"\nTabla guardada exitosamente como: {table_name}")

# %%
import pandas as pd
import requests
from io import StringIO

# Leer datos desde GitHub
url = "https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/202602/DATOS/DESEMPLEADOS.CSV"
response = requests.get(url)
response.encoding = 'utf-8'

# Crear DataFrame de pandas
df = pd.read_csv(StringIO(response.text),sep=';')

# Mostrar información del DataFrame
print(f"Dimensiones: {df.shape}")
print(f"\nPrimeras filas:")
display(df.head())
# Convertir a Spark DataFrame
df_spark = spark.createDataFrame(df)

# Guardar como tabla Delta en el catálogo
# Ajusta el nombre de la tabla según tu catálogo y esquema
table_name = "workspace.electiva.desempleados"
df_spark.write.format("delta").mode("overwrite").saveAsTable(table_name)

print(f"\nTabla guardada exitosamente como: {table_name}")
